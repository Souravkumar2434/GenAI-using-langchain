kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.24-py3-none-any.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ------ --------------------------------- 0.4/2.5 MB 12.2 MB/s eta 0:00:01
#      ------- -------------------------------- 0.5/2.5 MB 6.3 MB/s eta 0:00:01
#      ------------- -------------------------- 0.9/2.5 MB 7.0 MB/s eta 0:00:01
#      --------------- ------------------------ 1.0/2.5 MB 6.3 MB/s eta 0:00:01
#      -------------------- ------------------- 1.3/2.5 MB 5.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.4/2.5 MB 5.7 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.5/2.5 MB 5.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.8/2.5 MB 5.3 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.9/2.5 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.2/2.5 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.2/2.5 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 3.9 MB/s eta 0:00:00
# Collecting langsmith<0.4,>=0.1.17
#   Using cached langsmith-0.3.42-py3-none-any.whl (360 kB)
# Collecting requests<3,>=2
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting langchain-core<1.0.0,>=0.3.58
#   Using cached langchain_core-0.3.59-py3-none-any.whl (437 kB)
# Collecting PyYAML>=5.3
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Collecting SQLAlchemy<3,>=1.4
#   Using cached sqlalchemy-2.0.40-cp310-cp310-win_amd64.whl (2.1 MB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting pydantic<3.0.0,>=2.7.4
#   Using cached pydantic-2.11.4-py3-none-any.whl (443 kB)
# Collecting tenacity>=8.2.3
#   Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting tokenizers>=0.13.2
#   Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.33.0-py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.9 kB ? eta -:--:--
#      -------------------------------------- 118.9/118.9 kB 2.3 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting jsonschema>=4.19.0
#   Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Collecting httpx>=0.27.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.54b0-py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\004_genai\.venv\lib\site-packages (from chromadb) (4.13.2)
# Collecting importlib-resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.33.0-py3-none-any.whl (18 kB)
# Collecting grpcio>=1.58.0
#   Using cached grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.3/2.0 MB 9.3 MB/s eta 0:00:01
#      -------- ------------------------------- 0.4/2.0 MB 6.7 MB/s eta 0:00:01
#      --------------- ------------------------ 0.8/2.0 MB 6.8 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.8/2.0 MB 5.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.2/2.0 MB 5.3 MB/s eta 0:00:01
#      ------------------------- -------------- 1.3/2.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.4/2.0 MB 4.8 MB/s eta 0:00:01
#      --------------------------------- ------ 1.7/2.0 MB 5.0 MB/s eta 0:00:01
#      --------------------------------- ------ 1.7/2.0 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 4.4 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.22.0-cp310-cp310-win_amd64.whl (12.7 MB)
#      ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.7 MB 7.9 MB/s eta 0:00:02
#       --------------------------------------- 0.3/12.7 MB 7.9 MB/s eta 0:00:02
#      - -------------------------------------- 0.4/12.7 MB 3.3 MB/s eta 0:00:04
#      - -------------------------------------- 0.4/12.7 MB 3.3 MB/s eta 0:00:04
#      - -------------------------------------- 0.6/12.7 MB 2.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.6/12.7 MB 2.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.6/12.7 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.7 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.7 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.7 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.7 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.9/12.7 MB 1.6 MB/s eta 0:00:08
#      --- ------------------------------------ 1.0/12.7 MB 1.8 MB/s eta 0:00:07
#      --- ------------------------------------ 1.2/12.7 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.2/12.7 MB 1.9 MB/s eta 0:00:06
#      --- ------------------------------------ 1.2/12.7 MB 1.9 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.4/12.7 MB 1.9 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.6/12.7 MB 2.1 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.8/12.7 MB 2.2 MB/s eta 0:00:05
#      ------ --------------------------------- 2.2/12.7 MB 2.5 MB/s eta 0:00:05
#      ------- -------------------------------- 2.3/12.7 MB 2.5 MB/s eta 0:00:05
#      -------- ------------------------------- 2.5/12.7 MB 2.7 MB/s eta 0:00:04
#      -------- ------------------------------- 2.8/12.7 MB 2.8 MB/s eta 0:00:04
#      --------- ------------------------------ 3.0/12.7 MB 2.8 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.3/12.7 MB 3.0 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.7 MB 3.0 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.6/12.7 MB 3.1 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/12.7 MB 3.1 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.7 MB 3.1 MB/s eta 0:00:03
#      ------------ --------------------------- 4.0/12.7 MB 3.1 MB/s eta 0:00:03
#      ------------ --------------------------- 4.1/12.7 MB 3.0 MB/s eta 0:00:03
#      ------------ --------------------------- 4.1/12.7 MB 3.0 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.7 MB 3.0 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.7 MB 3.0 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.7 MB 2.8 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.7 MB 2.8 MB/s eta 0:00:03
#      ------------- -------------------------- 4.3/12.7 MB 2.7 MB/s eta 0:00:04
#      ------------- -------------------------- 4.3/12.7 MB 2.7 MB/s eta 0:00:04
#      -------------- ------------------------- 4.5/12.7 MB 2.7 MB/s eta 0:00:04
#      -------------- ------------------------- 4.5/12.7 MB 2.7 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.7 MB 2.6 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.7 MB 2.6 MB/s eta 0:00:04
#      -------------- ------------------------- 4.8/12.7 MB 2.6 MB/s eta 0:00:04
#      --------------- ------------------------ 4.9/12.7 MB 2.6 MB/s eta 0:00:04
#      --------------- ------------------------ 4.9/12.7 MB 2.6 MB/s eta 0:00:04
#      --------------- ------------------------ 5.0/12.7 MB 2.5 MB/s eta 0:00:04
#      --------------- ------------------------ 5.0/12.7 MB 2.5 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.1/12.7 MB 2.5 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.1/12.7 MB 2.5 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.1/12.7 MB 2.5 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.7 MB 2.4 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.4/12.7 MB 2.4 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.4/12.7 MB 2.4 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.4/12.7 MB 2.4 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.4/12.7 MB 2.3 MB/s eta 0:00:04
#      ------------------ --------------------- 5.7/12.7 MB 2.4 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.7 MB 2.5 MB/s eta 0:00:03
#      -------------------- ------------------- 6.4/12.7 MB 2.6 MB/s eta 0:00:03
#      --------------------- ------------------ 6.7/12.7 MB 2.7 MB/s eta 0:00:03
#      --------------------- ------------------ 6.9/12.7 MB 2.7 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.2/12.7 MB 2.8 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.4/12.7 MB 2.8 MB/s eta 0:00:02
#      ------------------------ --------------- 7.7/12.7 MB 2.8 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.7 MB 2.9 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.7 MB 2.9 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.7 MB 3.0 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.7 MB 3.0 MB/s eta 0:00:02
#      --------------------------- ------------ 8.8/12.7 MB 3.0 MB/s eta 0:00:02
#      ---------------------------- ----------- 8.9/12.7 MB 3.0 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.1/12.7 MB 3.0 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.3/12.7 MB 3.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.7 MB 3.0 MB/s eta 0:00:02
#      ------------------------------ --------- 9.6/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.1/12.7 MB 3.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.7 MB 3.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.5/12.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.6/12.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.7 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.7 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.7 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.7 MB 3.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.2/12.7 MB 3.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.2/12.7 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.7 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.7 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.7 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.7 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.7 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------- -- 11.8/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------- -- 11.8/12.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------- -- 11.8/12.7 MB 3.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.1/12.7 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  12.4/12.7 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.7 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.7/12.7 MB 3.0 MB/s eta 0:00:00
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ---------------------------------------- 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting rich>=10.11.0
#   Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Collecting typer>=0.9.0
#   Using cached typer-0.15.3-py3-none-any.whl (45 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.1.0-cp310-cp310-win_amd64.whl (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 2.0 MB/s eta 0:00:00
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting orjson>=3.9.12
#   Using cached orjson-3.10.18-cp310-cp310-win_amd64.whl (134 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.33.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 0.0/65.8 kB ? eta -:--:--
#      ---------------------------------------- 65.8/65.8 kB 3.7 MB/s eta 0:00:00
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
#      ---------------------------------------- 0.0/152.8 kB ? eta -:--:--
#      ------------------------------ ------- 122.9/152.8 kB 3.6 MB/s eta 0:00:01
#      ------------------------------ ------- 122.9/152.8 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 152.8/152.8 kB 1.3 MB/s eta 0:00:00
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting posthog>=2.4.0
#   Downloading posthog-4.0.1-py2.py3-none-any.whl (92 kB)
#      ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#      ---------------------------------------- 92.0/92.0 kB 2.6 MB/s eta 0:00:00
# Collecting fastapi==0.115.9
#   Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
#      ---------------------------------------- 0.0/94.9 kB ? eta -:--:--
#      ---------------------------------------- 94.9/94.9 kB 2.7 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3
#   Using cached uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Collecting numpy>=1.22.5
#   Using cached numpy-2.2.5-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting starlette<0.46.0,>=0.40.0
#   Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#      ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#      ---------------------------------------- 71.5/71.5 kB 2.0 MB/s eta 0:00:00
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.4.0
#   Using cached jiter-0.9.0-cp310-cp310-win_amd64.whl (208 kB)
# Collecting anyio<5,>=3.5.0
#   Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Collecting regex>=2022.1.18
#   Using cached regex-2024.11.6-cp310-cp310-win_amd64.whl (274 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Using cached pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0
#   Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Using cached aiohttp-3.11.18-cp310-cp310-win_amd64.whl (442 kB)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.6.0-cp310-cp310-win_amd64.whl (120 kB)
# Collecting yarl<2.0,>=1.17.0
#   Using cached yarl-1.20.0-cp310-cp310-win_amd64.whl (92 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.4.3-cp310-cp310-win_amd64.whl (38 kB)
# Collecting aiohappyeyeballs>=2.3.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting propcache>=0.2.0
#   Using cached propcache-0.3.1-cp310-cp310-win_amd64.whl (45 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\004_genai\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Collecting idna>=2.8
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=19.1 in c:\004_genai\.venv\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: colorama in c:\004_genai\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting certifi
#   Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.24.0-cp310-cp310-win_amd64.whl (234 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.40.1-py2.py3-none-any.whl (216 kB)
#      ---------------------------------------- 0.0/216.1 kB ? eta -:--:--
#      -------------------------------------- 216.1/216.1 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in c:\004_genai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Collecting urllib3>=1.24.2
#   Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB 3.2 MB/s eta 0:00:00
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\004_genai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      ---------- ----------------------------- 41.0/151.7 kB ? eta -:--:--
#      ----------------------------------- -- 143.4/151.7 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 151.7/151.7 kB 1.5 MB/s eta 0:00:00
# Collecting packaging>=19.1
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting zstandard<0.24.0,>=0.23.0
#   Using cached zstandard-0.23.0-cp310-cp310-win_amd64.whl (495 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Collecting protobuf
#   Using cached protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
# Collecting flatbuffers
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting sympy
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting importlib-metadata<8.7.0,>=6.0
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Collecting deprecated>=1.2.6
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Collecting opentelemetry-proto==1.33.0
#   Downloading opentelemetry_proto-1.33.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 0.0/55.9 kB ? eta -:--:--
#      ---------------------------------------- 55.9/55.9 kB 2.9 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.33.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.33.0-py3-none-any.whl (18 kB)
# Collecting googleapis-common-protos~=1.52
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Collecting protobuf
#   Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
# Collecting opentelemetry-instrumentation-asgi==0.54b0
#   Downloading opentelemetry_instrumentation_asgi-0.54b0-py3-none-any.whl (16 kB)
# Collecting opentelemetry-instrumentation==0.54b0
#   Downloading opentelemetry_instrumentation-0.54b0-py3-none-any.whl (31 kB)
# Collecting opentelemetry-util-http==0.54b0
#   Downloading opentelemetry_util_http-0.54b0-py3-none-any.whl (7.3 kB)
# Collecting opentelemetry-semantic-conventions==0.54b0
#   Downloading opentelemetry_semantic_conventions-0.54b0-py3-none-any.whl (194 kB)
#      ---------------------------------------- 0.0/194.9 kB ? eta -:--:--
#      -------------------------------------  194.6/194.9 kB 5.8 MB/s eta 0:00:01
#      -------------------------------------- 194.9/194.9 kB 3.9 MB/s eta 0:00:00
# Collecting wrapt<2.0.0,>=1.0.0
#   Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting pydantic-core==2.33.2
#   Using cached pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.0
#   Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Collecting python-dotenv>=0.21.0
#   Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.2-cp310-cp310-win_amd64.whl (105 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\004_genai\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting greenlet>=1
#   Using cached greenlet-3.2.2-cp310-cp310-win_amd64.whl (294 kB)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.31.2-py3-none-any.whl (484 kB)
#      ---------------------------------------- 0.0/484.2 kB ? eta -:--:--
#      -------------------- ----------------- 256.0/484.2 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------  481.3/484.2 kB 7.6 MB/s eta 0:00:01
#      -------------------------------------- 484.2/484.2 kB 5.0 MB/s eta 0:00:00
# Collecting click>=8.0.0
#   Downloading click-8.2.0-py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.2 kB ? eta -:--:--
#      -------------------------------------- 102.2/102.2 kB 3.0 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.0.5-cp310-cp310-win_amd64.whl (291 kB)
#      ---------------------------------------- 0.0/291.5 kB ? eta -:--:--
#      ------------------ ------------------- 143.4/291.5 kB 8.3 MB/s eta 0:00:01
#      -------------------------------------  286.7/291.5 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 291.5/291.5 kB 2.0 MB/s eta 0:00:00
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp310-cp310-win_amd64.whl (88 kB)
#      ---------------------------------------- 0.0/88.3 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/88.3 kB ? eta -:--:--
#      ---------------------------------------- 88.3/88.3 kB 1.0 MB/s eta 0:00:00
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
#      ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#      -------------------------------------  174.1/176.8 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------- 176.8/176.8 kB 3.5 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting filelock
#   Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Collecting zipp>=3.20
#   Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 86.8/86.8 kB 2.5 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#      ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#      ---------------------------------------- 83.2/83.2 kB 2.4 MB/s eta 0:00:00
# Collecting pyasn1<0.7.0,>=0.6.1
#   Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53917 sha256=601c1a0554d88091973d46b274b841e3859bf883571144127ff3eeafad14d234
#   Stored in directory: c:\users\sourav chaudhary\appdata\local\pip\cache\wheels\e1\26\51\d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, mpmath, flatbuffers, durationpy, zstandard, zipp, wrapt, websockets, websocket-client, urllib3, typing-inspection, tqdm, tomli, tenacity, sympy, sniffio, shellingham, rpds-py, regex, PyYAML, python-dotenv, pyreadline3, pyproject_hooks, pypdf, pydantic-core, pyasn1, protobuf, propcache, packaging, overrides, orjson, opentelemetry-util-http, oauthlib, numpy, mypy-extensions, multidict, mmh3, mdurl, jsonpointer, jiter, importlib-resources, idna, httpx-sse, httptools, h11, grpcio, greenlet, fsspec, frozenlist, filelock, distro, click, charset-normalizer, certifi, cachetools, bcrypt, backoff, attrs, async-timeout, asgiref, annotated-types, aiohappyeyeballs, yarl, uvicorn, typing-inspect, SQLAlchemy, rsa, requests, referencing, pydantic, pyasn1-modules, opentelemetry-proto, marshmallow, markdown-it-py, jsonpatch, importlib-metadata, humanfriendly, httpcore, googleapis-common-protos, deprecated, build, anyio, aiosignal, watchfiles, tiktoken, starlette, rich, requests-toolbelt, requests-oauthlib, pydantic-settings, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, jsonschema-specifications, huggingface-hub, httpx, google-auth, dataclasses-json, coloredlogs, aiohttp, typer, tokenizers, opentelemetry-semantic-conventions, openai, onnxruntime, langsmith, kubernetes, jsonschema, fastapi, opentelemetry-sdk, opentelemetry-instrumentation, langchain-core, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain_openai, opentelemetry-instrumentation-fastapi, langchain, langchain-community, chromadb
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.40 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.9.0 asgiref-3.8.1 async-timeout-4.0.3 attrs-25.3.0 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 cachetools-5.5.2 certifi-2025.4.26 charset-normalizer-3.4.2 chromadb-1.0.9 click-8.2.0 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.18 distro-1.9.0 durationpy-0.9 fastapi-0.115.9 filelock-3.18.0 flatbuffers-25.2.10 frozenlist-1.6.0 fsspec-2025.3.2 google-auth-2.40.1 googleapis-common-protos-1.70.0 greenlet-3.2.2 grpcio-1.71.0 h11-0.16.0 httpcore-1.0.9 httptools-0.6.4 httpx-0.28.1 httpx-sse-0.4.0 huggingface-hub-0.31.2 humanfriendly-10.0 idna-3.10 importlib-metadata-8.6.1 importlib-resources-6.5.2 jiter-0.9.0 jsonpatch-1.33 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2025.4.1 kubernetes-32.0.1 langchain-0.3.25 langchain-community-0.3.24 langchain-core-0.3.59 langchain-text-splitters-0.3.8 langchain_openai-0.3.16 langsmith-0.3.42 markdown-it-py-3.0.0 marshmallow-3.26.1 mdurl-0.1.2 mmh3-5.1.0 mpmath-1.3.0 multidict-6.4.3 mypy-extensions-1.1.0 numpy-2.2.5 oauthlib-3.2.2 onnxruntime-1.22.0 openai-1.78.1 opentelemetry-api-1.33.0 opentelemetry-exporter-otlp-proto-common-1.33.0 opentelemetry-exporter-otlp-proto-grpc-1.33.0 opentelemetry-instrumentation-0.54b0 opentelemetry-instrumentation-asgi-0.54b0 opentelemetry-instrumentation-fastapi-0.54b0 opentelemetry-proto-1.33.0 opentelemetry-sdk-1.33.0 opentelemetry-semantic-conventions-0.54b0 opentelemetry-util-http-0.54b0 orjson-3.10.18 overrides-7.7.0 packaging-24.2 posthog-4.0.1 propcache-0.3.1 protobuf-5.29.4 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.4 pydantic-core-2.33.2 pydantic-settings-2.9.1 pypdf-5.5.0 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 python-dotenv-1.1.0 referencing-0.36.2 regex-2024.11.6 requests-2.32.3 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rich-14.0.0 rpds-py-0.24.0 rsa-4.9.1 shellingham-1.5.4 sniffio-1.3.1 starlette-0.45.3 sympy-1.14.0 tenacity-9.1.2 tiktoken-0.9.0 tokenizers-0.21.1 tomli-2.2.1 tqdm-4.67.1 typer-0.15.3 typing-inspect-0.9.0 typing-inspection-0.4.0 urllib3-2.4.0 uvicorn-0.34.2 watchfiles-1.0.5 websocket-client-1.8.0 websockets-15.0.1 wrapt-1.17.2 yarl-1.20.0 zipp-3.21.0 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: c:\004_GenAI\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import Document
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings

# %%
store = Chroma(
    persist_directory="chroma_store",
    embedding_function=OpenAIEmbeddings(),
    collection_name="langchain"
)
# Out:
# C:\Users\Sourav Chaudhary\AppData\Local\Temp\ipykernel_31824\3749985634.py:3: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embedding_function=OpenAIEmbeddings(),
# C:\Users\Sourav Chaudhary\AppData\Local\Temp\ipykernel_31824\3749985634.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   store = Chroma(

# %%
doc1 = Document(
    page_content="Virat Kohli's aggressive batting, consistent performance, and leadership have made him one of India's greatest modern cricket captains.",
    metadata={"source": "Virat Kohli"}
)

doc2 = Document(
    page_content="Sachin Tendulkar, known as the 'Little Master', holds the record for the most runs in international cricket and is widely regarded as one of the greatest batsmen of all time.",
    metadata={"source": "Sachin Tendulkar"}
)

doc3 = Document(
    page_content = "Priyanka Chopra, Miss World 2000, transitioned from Bollywood to Hollywood, becoming a global star and successful producer and philanthropist.",
    metadata={"source": "Priyanka Chopra"}
)

doc4 = Document(
    page_content= "Narendra Modi, India’s Prime Minister, is known for his strong leadership, economic reforms, digital initiatives, and global diplomatic presence.",
    metadata={"source": "Narendra Modi"}
)

doc5 = Document(
    page_content="Ratan Tata’s visionary business leadership, philanthropy, and integrity have made him one of the most respected industrialists in India.",
    metadata={"source": "Ratan Tata"}
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
store.add_documents(docs)
# Out:
# ['4c7de2be-4d5f-4dc2-899f-338a0c116b93',
#  'd7f1889d-e584-4867-9785-907f869e7fa8',
#  '65927672-f2ff-4c44-8f5f-36c7a720db95',
#  '7b341c38-9aed-4d3e-848f-eb6c67edb4c3',
#  '40907a9e-9e67-4657-882e-84d8daca4885']

# %%
store.get(include= ["documents", "metadatas", "embeddings"])
# Out:
# {'ids': ['4c7de2be-4d5f-4dc2-899f-338a0c116b93',
#   'd7f1889d-e584-4867-9785-907f869e7fa8',
#   '65927672-f2ff-4c44-8f5f-36c7a720db95',
#   '7b341c38-9aed-4d3e-848f-eb6c67edb4c3',
#   '40907a9e-9e67-4657-882e-84d8daca4885'],
#  'embeddings': array([[-6.35834085e-03,  1.56749669e-03,  2.40070764e-02, ...,
#          -3.38901160e-03,  5.27600292e-03, -2.30509578e-03],
#         [ 3.88820609e-03, -7.15863006e-03,  2.22656317e-02, ...,
#          -1.22155268e-02, -7.99932331e-03, -6.56632334e-03],
#         [ 1.37962191e-03, -3.71621475e-02,  1.73475295e-02, ...,
#          -2.56447401e-02, -1.00955861e-02, -2.09572688e-02],
#         [-7.26699643e-03, -1.17659168e-02, -8.34877323e-03, ...,
#          -3.18933353e-02,  6.84562037e-05, -1.82756688e-02],
#         [ 2.35287496e-03, -1.19273812e-02,  8.39065854e-03, ...,
#          -4.08665929e-03, -3.87261179e-03, -9.63542704e-03]],
#        shape=(5, 1536)),
#  'documents': ["Virat Kohli's aggressive batting, consistent performance, and leadership have made him one of India's greatest modern cricket captains.",
#   "Sachin Tendulkar, known as the 'Little Master', holds the record for the most runs in international cricket and is widely regarded as one of the greatest batsmen of all time.",
#   'Priyanka Chopra, Miss World 2000, transitioned from Bollywood to Hollywood, becoming a global star and successful producer and philanthropist.',
#   'Narendra Modi, India’s Prime Minister, is known for his strong leadership, economic reforms, digital initiatives, and global diplomatic presence.',
#   'Ratan Tata’s visionary business leadership, philanthropy, and integrity have made him one of the most respected industrialists in India.'],
#  'uris': None,
#  'included': ['documents', 'metadatas', 'embeddings'],
#  'data': None,
#  'metadatas': [{'source': 'Virat Kohli'},
#   {'source': 'Sachin Tendulkar'},
#   {'source': 'Priyanka Chopra'},
#   {'source': 'Narendra Modi'},
#   {'source': 'Ratan Tata'}]}

# %%
store.similarity_search(
    "who is the best cricketer in India?",
    k=2
    )
# Out:
# [Document(metadata={'source': 'Virat Kohli'}, page_content="Virat Kohli's aggressive batting, consistent performance, and leadership have made him one of India's greatest modern cricket captains."),
#  Document(metadata={'source': 'Sachin Tendulkar'}, page_content="Sachin Tendulkar, known as the 'Little Master', holds the record for the most runs in international cricket and is widely regarded as one of the greatest batsmen of all time.")]

# %%
store.similarity_search_with_score(
    "who is the prime minister of India?",
    k=1
    )
# Out:
# [(Document(metadata={'source': 'Narendra Modi'}, page_content='Narendra Modi, India’s Prime Minister, is known for his strong leadership, economic reforms, digital initiatives, and global diplomatic presence.'),
#   0.26376402378082275)]

# %%
store.similarity_search_with_score(
    "who has most runs in international cricket?",
    k=1
    )
# Out:
# [(Document(metadata={'source': 'Sachin Tendulkar'}, page_content="Sachin Tendulkar, known as the 'Little Master', holds the record for the most runs in international cricket and is widely regarded as one of the greatest batsmen of all time."),
#   0.27090227603912354)]
